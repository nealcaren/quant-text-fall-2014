# %% [markdown]
# ### Your mission:
#
# Tell me something interesting about how the The New York Times covers abortion. I've pulled every story that the Times ran that contained the word abortion between 1987 and 2008 which includes 14,269 articles totalling 14,626,680 words (90 MB). This is a lot, so I would recommend restricting your analysis to just those that were nationally focused, which incluces just 5,406 and a mere 5,906,630 words (36 MB).
#
# This dataset of articles is not far from the one the data used in [DiMaggio, Paul, Manish Nag, and David Blei. "Exploiting affinities between topic modeling and the sociological perspective on culture: Application to newspaper coverage of US government arts funding." Poetics 41.6 (2013): 570-606.](http://www.sciencedirect.com/science/article/pii/S0304422X13000661). This should give you a starting point for thinking about the kinds of things that can be operationalized and the kinds of analysis that can be accomplished.
#
# There are two major goals for today, and keep them both in mind as you work on the mission.
# 2. Understanding the benefits and limitations of topic models in the social sciences.
# 1. Mastering the application of topic models in Python.
#
# As always, after inspecting the data, attempt to come up with your theoretical informed analysis plan, and then implement it!
#
# Teams:
# * Taylor and Ali
# * Karam and Mary Beth
# * Lena and Akram
# * Joseph, David And Didem
#
#
#
# Be preprared to present your results at 2pm.

# %%
# %matplotlib inline

import pandas as pd

import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
# Note that this will only work if you have stored the data in the current directory. 
# You can get the data from  
# https://github.com/nealcaren/quant-text-fall-2014/tree/master/times_data
# Remember that Pandas can read a file or a URL.

df = pd.read_json('times_abortion.json')

print 'Article Count:', len(df)
print 'Word Count:', df.word_count.sum()
df.head()
# Out:
# Article Count: 14269
# Word Count: 14626680
#                  byline                dsk  print_page_number print_section  \
# 1000008  Baker, Russell     Editorial Desk                 23             A
# 1000090     Gross, Jane      National Desk                 17             A
# 1000104      Barry, Dan  Metropolitan Desk                  1             A
# 1000208   Schmitt, Eric       Foreign Desk                  4             A
# 1000225  Purdum, Todd S      National Desk                  6             A
#
#          publication_day_of_month  publication_month  publication_year  \
# 1000008                         6                  3              1998
# 1000090                         6                  3              1998
# 1000104                         6                  3              1998
# 1000208                         7                  3              1998
# 1000225                         7                  3              1998
#
#                                                       text  \
# 1000008  Despite Monica Lewinsky and Stonewall Clinton,...
# 1000090  Contradicting Sgt. Maj. Gene C. McKinney, Sgt....
# 1000104  Just two months into his second term, Mayor Ru...
# 1000208  The Senate committee that controls spending bi...
# 1000225  Californians are long used to the televised cu...
#
#                                                      title  word_count
# 1000008                Observer; Comfort for the Afflicted         749
# 1000090       Ex-Top Soldier Is Contradicted By An Accuser         421
# 1000104  Giuliani Fund-Raising Points To Running for Hi...        1318
# 1000208  Senators Back Extra Military Spending but Faul...         820
# 1000225         Interest Groups Run Own Race in California        1169

# %%
dfn = pd.read_json('times_national_abortion.json')

print 'Article Count:', len(dfn)
print 'Word Count:', dfn.word_count.sum()
df.head()
# Out:
# Article Count: 5406
# Word Count: 5906630
#                  byline                dsk  print_page_number print_section  \
# 1000008  Baker, Russell     Editorial Desk                 23             A
# 1000090     Gross, Jane      National Desk                 17             A
# 1000104      Barry, Dan  Metropolitan Desk                  1             A
# 1000208   Schmitt, Eric       Foreign Desk                  4             A
# 1000225  Purdum, Todd S      National Desk                  6             A
#
#          publication_day_of_month  publication_month  publication_year  \
# 1000008                         6                  3              1998
# 1000090                         6                  3              1998
# 1000104                         6                  3              1998
# 1000208                         7                  3              1998
# 1000225                         7                  3              1998
#
#                                                       text  \
# 1000008  Despite Monica Lewinsky and Stonewall Clinton,...
# 1000090  Contradicting Sgt. Maj. Gene C. McKinney, Sgt....
# 1000104  Just two months into his second term, Mayor Ru...
# 1000208  The Senate committee that controls spending bi...
# 1000225  Californians are long used to the televised cu...
#
#                                                      title  word_count
# 1000008                Observer; Comfort for the Afflicted         749
# 1000090       Ex-Top Soldier Is Contradicted By An Accuser         421
# 1000104  Giuliani Fund-Raising Points To Running for Hi...        1318
# 1000208  Senators Back Extra Military Spending but Faul...         820
# 1000225         Interest Groups Run Own Race in California        1169

# %%
# LDA uses frequencies, but I find that NMF likes Tf-Idf better.

vectorizer = TfidfVectorizer(max_df=0.7, 
                             min_df=5)

# %%
# This may not be quick. The whole notebook takes my relatively modern MacBook Air 5 minutes to run.

vectorizer.fit(df['text'])
tfidf = vectorizer.transform(df['text'])

# %%
# This will not be quick. Note that more topics = more time.

number_of_topics = 20

nmf = NMF(n_components = number_of_topics, max_iter = 5000).fit(tfidf)

# %%
# Print out most informative features 
# This also stores the topics in a list topic_labels

feature_names = vectorizer.get_feature_names()
topic_labels = []

for topic_idx, topic in enumerate(nmf.components_):
    print("Topic #%d" % topic_idx)
    values = [topic[item] for  item in topic.argsort()[:-10 - 1:-1]]
    words = [feature_names[i] for i in topic.argsort()[:-10 - 1:-1]]
    print '-','\n- '.join(['%s (%.2f)' % c for c in zip(words,values)])
    topic_labels.append(" ".join([feature_names[i]
                    for i in topic.argsort()[:-3 - 1:-1]]))
    print ''
# Out:
# Topic #0:
# - gore (2.68)
# - mr (1.12)
# - bradley (0.88)
# - clinton (0.71)
# - al (0.39)
# - campaign (0.38)
# - vice (0.36)
# - president (0.27)
# - nader (0.26)
# - lieberman (0.22)
#
# Topic #1:
# - she (2.57)
# - her (2.30)
# - ms (0.98)
# - mother (0.28)
# - mrs (0.26)
# - woman (0.25)
# - husband (0.22)
# - herself (0.18)
# - baby (0.18)
# - when (0.17)
#
# Topic #2:
# - court (2.22)
# - justice (1.13)
# - law (0.75)
# - supreme (0.74)
# - justices (0.64)
# - case (0.61)
# - decision (0.51)
# - roe (0.43)
# - state (0.40)
# - ruling (0.39)
#
# Topic #3:
# - church (1.55)
# - catholic (1.27)
# - pope (1.09)
# - cardinal (0.96)
# - bishops (0.77)
# - bishop (0.76)
# - catholics (0.60)
# - vatican (0.53)
# - archbishop (0.47)
# - roman (0.39)
#
# Topic #4:
# - mrs (1.92)
# - whitman (1.79)
# - jersey (0.73)
# - governor (0.66)
# - she (0.64)
# - lazio (0.61)
# - her (0.59)
# - clinton (0.50)
# - state (0.38)
# - mcgreevey (0.34)
#
# Topic #5:
# - you (1.41)
# - we (1.12)
# - what (0.68)
# - my (0.65)
# - people (0.61)
# - there (0.57)
# - do (0.54)
# - our (0.54)
# - can (0.52)
# - so (0.50)
#
# Topic #6:
# - party (1.88)
# - republican (1.77)
# - republicans (1.19)
# - democrats (1.01)
# - democratic (0.93)
# - state (0.66)
# - voters (0.64)
# - percent (0.59)
# - election (0.55)
# - candidates (0.53)
#
# Topic #7:
# - clinic (1.78)
# - clinics (1.22)
# - protesters (0.82)
# - rescue (0.81)
# - operation (0.73)
# - anti (0.68)
# - police (0.65)
# - arrested (0.49)
# - federal (0.48)
# - were (0.42)
# Topic #8:
# - dole (3.22)
# - mr (1.31)
# - buchanan (0.98)
# - clinton (0.64)
# - kemp (0.42)
# - bob (0.39)
# - gramm (0.39)
# - convention (0.38)
# - party (0.34)
# - republican (0.32)
#
# Topic #9:
# - bill (1.75)
# - house (1.30)
# - senate (1.00)
# - clinton (0.91)
# - veto (0.68)
# - congress (0.68)
# - measure (0.63)
# - legislation (0.58)
# - spending (0.58)
# - president (0.54)
#
# Topic #10:
# - 95 (2.46)
# - 25 (0.57)
# - 24 (0.55)
# - novel (0.44)
# - book (0.43)
# - 11 (0.38)
# - books (0.36)
# - 12 (0.35)
# - schuster (0.34)
# - 14 (0.34)
#
# Topic #11:
# - percent (0.92)
# - children (0.76)
# - health (0.75)
# - teen (0.68)
# - care (0.68)
# - school (0.54)
# - state (0.53)
# - education (0.52)
# - parents (0.49)
# - welfare (0.46)
#
# Topic #12:
# - judge (2.84)
# - bork (1.52)
# - souter (0.73)
# - thomas (0.71)
# - nomination (0.64)
# - court (0.63)
# - confirmation (0.56)
# - senate (0.54)
# - senator (0.51)
# - committee (0.50)
#
# Topic #13:
# - women (2.96)
# - abortions (0.65)
# - woman (0.53)
# - men (0.47)
# - rights (0.46)
# - editor (0.41)
# - pro (0.40)
# - choice (0.40)
# - life (0.36)
# - pregnancy (0.32)
#
# Topic #14:
# - bush (3.90)
# - mr (1.64)
# - president (0.77)
# - mccain (0.69)
# - reagan (0.44)
# - george (0.42)
# - dukakis (0.41)
# - campaign (0.38)
# - quayle (0.35)
# - vice (0.28)
#
# Topic #15:
# - drug (1.81)
# - ru (1.63)
# - 486 (1.62)
# - pill (1.08)
# - roussel (0.69)
# - company (0.54)
# - mifepristone (0.51)
# - french (0.45)
# - uclaf (0.38)
# - surgical (0.38)
#
# Topic #16:
# - population (1.21)
# - china (1.12)
# - nations (1.11)
# - united (1.06)
# - planning (1.00)
# - family (0.73)
# - countries (0.67)
# - chinese (0.66)
# - international (0.66)
# - world (0.58)
# Topic #17:
# - giuliani (3.00)
# - dinkins (1.33)
# - mayor (1.26)
# - mr (1.09)
# - city (0.81)
# - york (0.53)
# - lazio (0.43)
# - koch (0.38)
# - yesterday (0.33)
# - rudolph (0.32)
#
# Topic #18:
# - mr (3.83)
# - pataki (0.65)
# - amato (0.64)
# - campaign (0.56)
# - state (0.46)
# - cuomo (0.43)
# - governor (0.43)
# - him (0.41)
# - race (0.32)
# - senator (0.32)
#
# Topic #19:
# - dr (2.81)
# - medical (0.80)
# - cells (0.64)
# - doctors (0.59)
# - research (0.58)
# - foster (0.57)
# - fetal (0.57)
# - health (0.53)
# - tissue (0.52)
# - patients (0.46)

# %%
# Get some predicted values. Takes a tfidf.

y_hat = nmf.transform(tfidf)

# %%
# get the most likely topic and add it as a column
topics = []
for row in y_hat:
    topics.append(topic_labels[np.argsort(row)[0]])
    
df['top_topic'] = topics

# %%
# get the full suite of predictions as values
# This is normalized so that the topic values for a given article sum to 1

y_norm = [y/ y.sum() for y in y_hat] #Normalize

df_y_hat = pd.DataFrame(y_norm, 
                        columns=topic_labels,  # Use our informative topic names
                        index=df.index.values) # Makes merge easier

df_topics = df.join(df_y_hat) # This is a new data set, so you can remerge

# %%
#an example of the stats could do

for topic in topic_labels:
    print df_topics[topic].mean(), topic
# Out:
# 0.0358335251903 gore mr bradley
# 0.0678877400687 court justice law
# 0.0508140434073 dr medical health
# 0.0596895877918 church catholic pope
# 0.0571415795769 party republican platform
# 0.0281974330593 95 25 24
# 0.0512134159213 bush mr president
# 0.0340913871595 judge bork souter
# 0.0640827560929 house clinton senate
# 0.0347392110001 dole mr buchanan
# 0.0546154243498 population planning nations
# 0.0767100844845 mr republican state
# 0.0288833196368 cells research tissue
# 0.0475806548793 clinic clinics protesters
# 0.0269208243834 mrs whitman jersey
# 0.0681708102034 women ms abortions
# 0.0211392526363 drug ru 486
# 0.026087049339 giuliani mr dinkins
# 0.123480218835 people ms like
# 0.0427216819846 mr pataki amato

# %%
df_topics.groupby('publication_year').mean()
# Out:
#                   print_page_number  publication_day_of_month  \
# publication_year
# 1987                      16.078125                 15.440625
# 1988                      16.131772                 15.781845
# 1989                      15.372093                 15.536906
# 1990                      14.048096                 15.927856
# 1991                      13.740741                 15.361111
# 1992                      13.712329                 15.927478
# 1993                      13.840438                 15.993910
# 1994                      12.462985                 14.862515
# 1995                      13.065410                 14.683278
# 1996                      13.109336                 14.906644
# 1997                      13.075931                 15.842407
# 1998                      12.952333                 15.615619
# 1999                      13.520223                 16.460251
# 2000                      14.455581                 15.667426
# 2001                      12.358736                 15.568773
# 2002                      14.284483                 15.577586
# 2003                      16.865546                 14.554622
# 2004                      13.968750                 15.895833
# 2005                      17.229730                 14.310811
# 2006                      14.105000                 15.876847
# 2007                      12.122222                 15.611111
#
#                   publication_month   word_count  gore mr bradley  \
# publication_year
# 1987                       6.889062  1037.596875         0.013062
# 1988                       7.007321   919.093704         0.018898
# 1989                       7.145602   922.744186         0.010631
# 1990                       6.660321   993.942886         0.012016
# 1991                       7.291005   875.859788         0.009539
# 1992                       6.970185  1002.409347         0.043044
# 1993                       6.456760  1103.561510         0.024206
# 1994                       7.203290  1082.405405         0.023328
# 1995                       6.763012  1053.384275         0.020591
# 1996                       6.521447  1105.935240         0.025712
# 1997                       6.978510  1094.520057         0.022722
# 1998                       6.907708  1056.229209         0.027463
# 1999                       6.859135  1233.340307         0.051156
# 2000                       6.397115  1153.927866         0.160920
# 2001                       4.355019  1026.721190         0.024562
# 2002                       6.672414   944.560345         0.026272
# 2003                       6.739496   555.067227         0.009983
# 2004                       7.442708   583.322917         0.012243
# 2005                       7.198198   626.756757         0.010039
# 2006                       5.783251   847.177340         0.012318
# 2007                       3.300000   781.288889         0.021512
#
#                   court justice law  dr medical health  church catholic pope  \
# publication_year
# 1987                       0.097396           0.060587              0.092524
# 1988                       0.079396           0.053036              0.053688
# 1989                       0.130093           0.067381              0.046344
# 1990                       0.085574           0.045054              0.102904
# 1991                       0.102363           0.062877              0.063908
# 1992                       0.071893           0.030479              0.033666
# 1993                       0.070857           0.077052              0.056207
# 1994                       0.064905           0.064554              0.056195
# 1995                       0.044787           0.083096              0.076079
# 1996                       0.036355           0.029837              0.038603
# 1997                       0.059533           0.060747              0.065003
# 1998                       0.034178           0.057726              0.045059
# 1999                       0.055697           0.035389              0.066548
# 2000                       0.047862           0.031540              0.054476
# 2001                       0.051293           0.042686              0.050982
# 2002                       0.063409           0.052596              0.064712
# 2003                       0.055296           0.054321              0.039519
# 2004                       0.059577           0.031000              0.170174
# 2005                       0.090207           0.030611              0.073633
# 2006                       0.068902           0.034938              0.038151
# 2007                       0.101952           0.031070              0.033012
#
#                   party republican platform  95 25 24    ...     \
# publication_year                                         ...
# 1987                               0.033881  0.024220    ...
# 1988                               0.053024  0.027054    ...
# 1989                               0.031252  0.026215    ...
# 1990                               0.044839  0.023684    ...
# 1991                               0.026945  0.020312    ...
# 1992                               0.076023  0.019914    ...
# 1993                               0.036414  0.034490    ...
# 1994                               0.050726  0.023520    ...
# 1995                               0.068480  0.024624    ...
# 1996                               0.109390  0.019184    ...
# 1997                               0.049072  0.025290    ...
# 1998                               0.061258  0.023378    ...
# 1999                               0.062988  0.022525    ...
# 2000                               0.069495  0.016007    ...
# 2001                               0.040053  0.040324    ...
# 2002                               0.040770  0.026255    ...
# 2003                               0.053010  0.042566    ...
# 2004                               0.057674  0.031449    ...
# 2005                               0.045787  0.179883    ...
# 2006                               0.059957  0.117163    ...
# 2007                               0.053122  0.087377    ...
#
#                   population planning nations  mr republican state  \
# publication_year
# 1987                                 0.081611             0.040472
# 1988                                 0.072635             0.068815
# 1989                                 0.056746             0.072783
# 1990                                 0.052115             0.114025
# 1991                                 0.064820             0.044731
# 1992                                 0.042105             0.086067
# 1993                                 0.057861             0.044883
# 1994                                 0.072791             0.079209
# 1995                                 0.058084             0.051223
# 1996                                 0.040071             0.097379
# 1997                                 0.066867             0.056209
# 1998                                 0.055877             0.115560
# 1999                                 0.061454             0.062307
# 2000                                 0.031736             0.088508
# 2001                                 0.054684             0.082735
# 2002                                 0.071979             0.146718
# 2003                                 0.062391             0.040871
# 2004                                 0.033617             0.068182
# 2005                                 0.032185             0.037664
# 2006                                 0.042576             0.099477
# 2007                                 0.038568             0.072421
#
#                   cells research tissue  clinic clinics protesters  \
# publication_year
# 1987                           0.031659                   0.037868
# 1988                           0.038239                   0.050122
# 1989                           0.034361                   0.056964
# 1990                           0.026436                   0.044151
# 1991                           0.026793                   0.062423
# 1992                           0.031344                   0.041717
# 1993                           0.015811                   0.064460
# 1994                           0.014948                   0.080529
# 1995                           0.016017                   0.068693
# 1996                           0.019533                   0.031189
# 1997                           0.036049                   0.044989
# 1998                           0.023804                   0.054153
# 1999                           0.029933                   0.042405
# 2000                           0.019501                   0.018913
# 2001                           0.062117                   0.047477
# 2002                           0.042075                   0.056218
# 2003                           0.079818                   0.066128
# 2004                           0.079784                   0.032475
# 2005                           0.029561                   0.036765
# 2006                           0.062200                   0.018421
# 2007                           0.052941                   0.026113
#
#                   mrs whitman jersey  women ms abortions  drug ru 486  \
# publication_year
# 1987                        0.011171            0.055880     0.014596
# 1988                        0.013610            0.065434     0.038249
# 1989                        0.018407            0.077171     0.022146
# 1990                        0.014907            0.069399     0.023694
# 1991                        0.011360            0.077972     0.028532
# 1992                        0.019782            0.085820     0.019573
# 1993                        0.025750            0.076564     0.023507
# 1994                        0.026017            0.069725     0.017058
# 1995                        0.026639            0.053164     0.012264
# 1996                        0.031042            0.048318     0.020521
# 1997                        0.054031            0.080167     0.023658
# 1998                        0.032660            0.069413     0.015702
# 1999                        0.046123            0.050060     0.018823
# 2000                        0.043970            0.042960     0.022533
# 2001                        0.035458            0.057140     0.017795
# 2002                        0.029891            0.094442     0.010625
# 2003                        0.012550            0.159312     0.014042
# 2004                        0.019164            0.114356     0.027721
# 2005                        0.016483            0.097684     0.023273
# 2006                        0.018968            0.122815     0.029100
# 2007                        0.012229            0.083278     0.015896
#
#                   giuliani mr dinkins  people ms like  mr pataki amato
# publication_year
# 1987                         0.016393        0.124166         0.022838
# 1988                         0.013891        0.119832         0.025828
# 1989                         0.062115        0.126975         0.027854
# 1990                         0.014248        0.121351         0.043393
# 1991                         0.010961        0.126635         0.027325
# 1992                         0.016465        0.131338         0.061834
# 1993                         0.056577        0.155919         0.028816
# 1994                         0.023994        0.110916         0.092517
# 1995                         0.015796        0.125740         0.033118
# 1996                         0.016263        0.118087         0.036658
# 1997                         0.025400        0.148564         0.042747
# 1998                         0.025967        0.132262         0.079051
# 1999                         0.032756        0.140397         0.049157
# 2000                         0.034758        0.097493         0.031331
# 2001                         0.024889        0.100591         0.049060
# 2002                         0.017899        0.097881         0.036671
# 2003                         0.015675        0.132637         0.020225
# 2004                         0.010045        0.107228         0.017171
# 2005                         0.014569        0.093052         0.018048
# 2006                         0.016103        0.114982         0.030360
# 2007                         0.100654        0.109495         0.026641
#
# [21 rows x 24 columns]

# %%
df_topics['decade'] =df_topics['publication_year'] > 1999

# %%
df_topics.groupby('decade').mean()
# Out:
#         print_page_number  publication_day_of_month  publication_month  \
# decade
# False           13.849621                  15.54402           6.883107
# True            14.234073                  15.51877           6.021452
#
#         publication_year   word_count  gore mr bradley  court justice law  \
# decade
# False        1993.112448  1036.046722         0.023789           0.070563
# True         2001.735073   980.032892         0.085233           0.056916
#
#         dr medical health  church catholic pope  party republican platform  \
# decade
# False            0.054512              0.059326                   0.056926
# True             0.035647              0.061179                   0.058027
#
#                   ...              population planning nations  \
# decade            ...
# False             ...                                 0.058107
# True              ...                                 0.040295
#
#         mr republican state  cells research tissue  clinic clinics protesters  \
# decade
# False              0.075266               0.026097                   0.051743
# True               0.082633               0.040312                   0.030507
#
#         mrs whitman jersey  women ms abortions  drug ru 486  \
# decade
# False             0.025270            0.067942     0.021065
# True              0.033692            0.069110     0.021444
#
#         giuliani mr dinkins  people ms like  mr pataki amato
# decade
# False              0.025422        0.128822         0.045277
# True               0.028816        0.101571         0.032242
#
# [2 rows x 25 columns]
