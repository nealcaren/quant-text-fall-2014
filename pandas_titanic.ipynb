# %%
# %matplotlib inline

import pandas as pd
import statsmodels.api as sm
import numpy as np

import matplotlib.pyplot as plt

from operator import itemgetter
from scipy.stats import randint as sp_randint

from sklearn.linear_model import LogisticRegression
from sklearn.grid_search import RandomizedSearchCV
from sklearn.grid_search import GridSearchCV
from sklearn.pipeline import Pipeline

try:
    import seaborn as sns
except:
    print 'Your graphs will be ugly'

# %%
# where the csv file lives is

data_url = 'https://kaggle2.blob.core.windows.net/competitions-data/kaggle/3136/train.csv?sv=2012-02-12&se=2014-11-13T14%3A48%3A10Z&sr=b&sp=r&sig=ZFFH80A%2BUCSXSdrghKUAXzr8PC1gvAct7VkanGEvhLA%3D'

# %%
# Pandas can read (and write) a lot of different file formats, and it doesn't care if they are local or on the web
# see http://pandas.pydata.org/pandas-docs/dev/io.html

df = pd.read_csv(data_url)

# %%
# take a look -- it's a dataframe!
# the number to the left is the index, a unique identifier. You can change this to something meaningful if you want.

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# VARIABLE DESCRIPTIONS:
#
# (https://www.kaggle.com/c/titanic-gettingStarted/data)
#
# survival        Survival
#                 (0 = No; 1 = Yes)
# pclass          Passenger Class
#                 (1 = 1st; 2 = 2nd; 3 = 3rd)
# name            Name
# sex             Sex
# age             Age
# sibsp           Number of Siblings/Spouses Aboard
# parch           Number of Parents/Children Aboard
# ticket          Ticket Number
# fare            Passenger Fare
# cabin           Cabin
# embarked        Port of Embarkation
#                 (C = Cherbourg; Q = Queenstown; S = Southampton)
#
# SPECIAL NOTES:
# Pclass is a proxy for socio-economic status (SES)
#  1st ~ Upper; 2nd ~ Middle; 3rd ~ Lower
#
# Age is in Years; Fractional if Age less than One (1)
#  If the Age is Estimated, it is in the form xx.5
#
# With respect to the family relation variables (i.e. sibsp and parch)
# some relations were ignored.  The following are the definitions used
# for sibsp and parch.
#
# Sibling:  Brother, Sister, Stepbrother, or Stepsister of Passenger Aboard Titanic
# Spouse:   Husband or Wife of Passenger Aboard Titanic (Mistresses and Fiances Ignored)
# Parent:   Mother or Father of Passenger Aboard Titanic
# Child:    Son, Daughter, Stepson, or Stepdaughter of Passenger Aboard Titanic
#
# Other family relatives excluded from this study include cousins,
# nephews/nieces, aunts/uncles, and in-laws.  Some children travelled
# only with a nanny, therefore parch=0 for them.  As well, some
# travelled with very close friends or neighbors in a village, however,
# the definitions do not support such relations.

# %%
# You can get all the columns in a list like object
print df.columns
# Out:
# Index([u'PassengerId', u'Survived', u'Pclass', u'Name', u'Sex', u'Age', u'SibSp', u'Parch', u'Ticket', u'Fare', u'Cabin', u'Embarked'], dtype='object')

# %%
# You can also get some summary statistics.

df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# There's also basic stats. Note that you can all columns similar to dictionary entries. 

pd.crosstab(df['Sex'], df['Survived'])
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
# You can collapse the dataframe using "groupby"

df.groupby('Sex').describe()
# Out:
#                      Age        Fare       Parch  PassengerId      Pclass  \
# Sex
# female count  261.000000  314.000000  314.000000   314.000000  314.000000
#        mean    27.915709   44.479818    0.649682   431.028662    2.159236
#        std     14.110146   57.997698    1.022846   256.846324    0.857290
#        min      0.750000    6.750000    0.000000     2.000000    1.000000
#        25%     18.000000   12.071875    0.000000   231.750000    1.000000
#        50%     27.000000   23.000000    0.000000   414.500000    2.000000
#        75%     37.000000   55.000000    1.000000   641.250000    3.000000
#        max     63.000000  512.329200    6.000000   889.000000    3.000000
# male   count  453.000000  577.000000  577.000000   577.000000  577.000000
#        mean    30.726645   25.523893    0.235702   454.147314    2.389948
#        std     14.678201   43.138263    0.612294   257.486139    0.813580
#        min      0.420000    0.000000    0.000000     1.000000    1.000000
# ...

# %%
# you can create new columns 
df['age_squared'] = df['Age'] * df['Age']

# Note the double brackets if you want to only look at a few columns. It's a list!
df[['Age','age_squared']].describe()
# Out:
#               Age  age_squared
# count  714.000000   714.000000
# mean    29.699118  1092.761169
# std     14.526497   991.079188
# min      0.420000     0.176400
# 25%     20.125000   405.062500
# 50%     28.000000   784.000000
# 75%     38.000000  1444.000000
# max     80.000000  6400.000000

# %%
# More complex column functions can be done with .apply

def ismale(text):
    if text == 'male':
        return 1
    return 0

df['Male'] = df['Sex'].apply(ismale)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  age_squared        Male
# count  891.000000  891.000000   714.000000  891.000000
# mean     0.381594   32.204208  1092.761169    0.647587
# std      0.806057   49.693429   991.079188    0.477990
# min      0.000000    0.000000     0.176400    0.000000
# 25%      0.000000    7.910400   405.062500    0.000000
# ...

# %% [markdown]
# ### Your mission 1. Create a new column in the dataframe that contains just the person's title, such as "Mr", "Mrs", "Miss", "Master" or "Lady".

# %%
# Pandas has some built in abilities to visualize the data, which is  useful for things descriptive statics. 
# %matplotlib inline allows the plots to be displayed in an IPython notebook

df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10c87b650>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10ccb3850>]], dtype=object)

# %%
df.groupby('Male').hist()
# Out:
# Male
# 0       [[Axes(0.125,0.684722;0.215278x0.215278), Axes...
# 1       [[Axes(0.125,0.684722;0.215278x0.215278), Axes...
# dtype: object

# %%
# More statitics. Note the string variables are dropped

df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
# age_squared     0.030276 -0.055645 -0.367118  0.953231 -0.212512 -0.111483
# Male            0.042939 -0.543351  0.131900  0.093254 -0.114631 -0.245489
#
#                  Fare  age_squared      Male
# PassengerId  0.012658     0.030276  0.042939
# Survived     0.257307    -0.055645 -0.543351
# Pclass      -0.549500    -0.367118  0.131900
# ...

# %% [markdown]
# ### Your mission 2. Using groupby, look to see if any of the correlations with survival vary by sex, Pclass, or any other categorical variable.

# %%
# Pandas can be used to quickly compute summary stats for a single variable. 

df["Age"].mean()
# Out:
# 29.69911764705882

# %%
# This can be useful is you want to fill in missing data

df["Age_imputed"] = df['Age'].fillna(df["Age"].mean())

# %%
df[['Age','Age_imputed']].describe()
# Out:
#               Age  Age_imputed
# count  714.000000   891.000000
# mean    29.699118    29.699118
# std     14.526497    13.002015
# min      0.420000     0.420000
# 25%     20.125000    22.000000
# 50%     28.000000    29.699118
# 75%     38.000000    35.000000
# max     80.000000    80.000000

# %%
# This can be combined with groupby to create more complex imputations

df["Age_imputed"] = df["Age"].fillna(df.groupby("Sex")["Age"].transform("mean"))

# %%
df[['Age','Age_imputed']].describe()
# Out:
#               Age  Age_imputed
# count  714.000000   891.000000
# mean    29.699118    29.736034
# std     14.526497    13.014897
# min      0.420000     0.420000
# 25%     20.125000    22.000000
# 50%     28.000000    30.000000
# 75%     38.000000    35.000000
# max     80.000000    80.000000

# %%
# Let's run a basic regression. Don't forget to create a intercept/consant

df['Intercept'] = 1

# %%
# The Python package statsmodel (imported as sm) has many of the basic regression functions we know and love.



predictors = ['Intercept','Age_imputed','Male']

# Fromat is Y, X, where Y is list-like object, and X is a list of lists. It works with lists or with df columns.

logit = sm.Logit(df['Survived'], df[predictors])

results = logit.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.514614
#          Iterations 5
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  891
# Model:                          Logit   Df Residuals:                      888
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 10 Nov 2014   Pseudo R-squ.:                  0.2272
# Time:                        10:21:05   Log-Likelihood:                -458.52
# converged:                       True   LL-Null:                       -593.33
#                                         LLR p-value:                 2.845e-59
# ...
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# ...

# %%
# We can create a new variable with the predictions 

df['Prediction'] = results.predict(df[predictors])

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  age_squared        Male  Age_imputed  \
# count  891.000000  891.000000   714.000000  891.000000   891.000000
# mean     0.381594   32.204208  1092.761169    0.647587    29.736034
# std      0.806057   49.693429   991.079188    0.477990    13.014897
# min      0.000000    0.000000     0.176400    0.000000     0.420000
# ...

# %%
#Pandas can also create dummy variables for when you want to include categorical variables

dummy_class = pd.get_dummies(df['Pclass'], prefix='class')

dummy_class.describe()
# Out:
#           class_1     class_2     class_3
# count  891.000000  891.000000  891.000000
# mean     0.242424    0.206510    0.551066
# std      0.428790    0.405028    0.497665
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000
# 75%      0.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000

# %%
# We now join this new dataframe with our old df. We only want to two columns, so we list them.

df = df.join(dummy_class[['class_2','class_3']])

# %%
# Run the regression model again.

predictors = predictors + ['class_2', u'class_3']

logit = sm.Logit(df['Survived'], df[predictors])
results = logit.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.451580
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:               Survived   No. Observations:                  891
# Model:                          Logit   Df Residuals:                      886
# Method:                           MLE   Df Model:                            4
# Date:                Mon, 10 Nov 2014   Pseudo R-squ.:                  0.3219
# Time:                        10:21:05   Log-Likelihood:                -402.36
# converged:                       True   LL-Null:                       -593.33
#                                         LLR p-value:                 2.219e-81
# ...
#                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# ...

# %%
#  In case you were wondering, we could also do this in Scikit, but the results aren't printed fancy.

lr = LogisticRegression(fit_intercept=False, C=1e9)
lr.fit(df[predictors],df['Survived'])
print lr.coef_
# Out:
# [[ 3.5525063  -0.0338052  -2.59261917 -1.12578177 -2.3391317 ]]

# %% [markdown]
# ### Your Mission 3: Create a logisitc regression model that includes one additional continuous measure and one additional categorical measure.

# %% [markdown]
# ### Your Mission 4: Create a better imputed measure of age that includes only title (e.g. "Mr.", "Master") as a predictor. Does this improve the fit of your model?

# %% [markdown]
# ### Your Mission 5: Try using a random forrest classifier.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, roc_curve, auc, precision_recall_curve

# %%
clf = RandomForestClassifier(oob_score = True, 
                             criterion='gini', 
                             n_estimators=100,  
                             min_samples_leaf=20, 
                             max_features=2)

# %%
X_train, X_test, y_train, y_test = train_test_split(df[predictors],df['Survived'], test_size=.4)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, compute_importances=None,
#             criterion='gini', max_depth=None, max_features=2,
#             max_leaf_nodes=None, min_density=None, min_samples_leaf=20,
#             min_samples_split=2, n_estimators=100, n_jobs=1,
#             oob_score=True, random_state=None, verbose=0)

# %%
def summary(classifier):
    print 'Training set score: %.1f%%' % (classifier.score(X_train, y_train)*100)
    print 'Test set score: %.1f%%' %(classifier.score(X_test, y_test)*100)
    preds = classifier.predict(X_test)
    print classification_report(np.array(y_test), preds)
    print 'Confusion matrix: '
    print pd.crosstab(y_test, preds, rownames=["Actual"], colnames=["Predicted"])

summary(clf)
# Out:
# Training set score: 80.7%
# Test set score: 79.0%
#              precision    recall  f1-score   support
#
#           0       0.80      0.88      0.84       218
#           1       0.77      0.65      0.71       139
#
# avg / total       0.79      0.79      0.79       357
#
# Confusion matrix:
# Predicted    0   1
# Actual
# 0          191  27
# 1           48  91

# %%
importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

feature_count = len(importances)

# Print the feature ranking
print("Feature ranking:")

for f in range(feature_count):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(feature_count), importances[indices],
       color="r", yerr=std[indices], align="center", orientation = "vertical")
plt.xticks(range(feature_count), [predictors[i] for i in indices])
plt.xlim([-1, feature_count])
plt.show()
# Out:
# Feature ranking:
# 1. feature 2 (0.654916)
# 2. feature 4 (0.190572)
# 3. feature 1 (0.126734)
# 4. feature 3 (0.027777)
# 5. feature 0 (0.000000)

# %%
lr.fit(X_train, y_train)
summary(lr)
# Out:
# Training set score: 80.0%
# Test set score: 79.6%
#              precision    recall  f1-score   support
#
#           0       0.81      0.87      0.84       218
#           1       0.77      0.68      0.72       139
#
# avg / total       0.79      0.80      0.79       357
#
# Confusion matrix:
# Predicted    0   1
# Actual
# 0          189  29
# 1           44  95

# %%
def roc(classifier):
    full_probs = classifier.predict_proba(X_test)
    fpr_full, tpr_full, thresholds_full = roc_curve(y_test, full_probs[:, 1])
    roc_auc_full = auc(fpr_full, tpr_full)
    
    plt.figure(figsize=(6, 5))
    plt.plot(fpr_full, tpr_full, label='Full random forest ROC curve (area = %0.2f)' % roc_auc_full)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver operating characteristic curve')
    plt.legend(loc="lower right");

# %%
roc(lr)

# %%
roc(clf)

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['Age_imputed']],df['Survived'], test_size=.4)
lr.fit(X_train, y_train)
roc(lr)
